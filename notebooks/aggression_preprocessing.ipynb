# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

import sys
sys.path.append('../')

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Download data
#
# only if it doesn't already exist

# %%
from data.data import download_data

download_data()

# %% [markdown]
# ## Load data

# %%
aggression_comments = pd.read_csv('../data/aggression_annotated_comments.tsv',  sep='\t') 
aggression_annotations = pd.read_csv('../data/aggression_annotations.tsv', sep='\t')

aggression_df_full = aggression_annotations.merge(aggression_comments)

# %%
aggression_df_full
# Out:
#             rev_id  worker_id  aggression  aggression_score  \
# 0            37675       1362         1.0              -1.0
# 1            37675       2408         0.0               1.0
# 2            37675       1493         0.0               0.0
# 3            37675       1439         0.0               0.0
# 4            37675        170         0.0               0.0
# ...            ...        ...         ...               ...
# 1365212  699897151        628         0.0               0.0
# 1365213  699897151         15         0.0               0.0
# 1365214  699897151         57         0.0               0.0
# 1365215  699897151       1815         0.0               0.0
# 1365216  699897151        472         0.0               0.0
#
#                                                    comment  year  logged_in  \
# 0        `-NEWLINE_TOKENThis is not ``creative``.  Thos...  2002       True
# 1        `-NEWLINE_TOKENThis is not ``creative``.  Thos...  2002       True
# 2        `-NEWLINE_TOKENThis is not ``creative``.  Thos...  2002       True
# 3        `-NEWLINE_TOKENThis is not ``creative``.  Thos...  2002       True
# 4        `-NEWLINE_TOKENThis is not ``creative``.  Thos...  2002       True
# ...                                                    ...   ...        ...
# 1365212  Alternate option===NEWLINE_TOKENIs there perha...  2016       True
# 1365213  Alternate option===NEWLINE_TOKENIs there perha...  2016       True
# 1365214  Alternate option===NEWLINE_TOKENIs there perha...  2016       True
# 1365215  Alternate option===NEWLINE_TOKENIs there perha...  2016       True
# 1365216  Alternate option===NEWLINE_TOKENIs there perha...  2016       True
#
#               ns   sample  split
# 0        article   random  train
# 1        article   random  train
# 2        article   random  train
# 3        article   random  train
# 4        article   random  train
# ...          ...      ...    ...
# 1365212  article  blocked  train
# 1365213  article  blocked  train
# 1365214  article  blocked  train
# 1365215  article  blocked  train
# 1365216  article  blocked  train
#
# [1365217 rows x 10 columns]

# %% [markdown]
# ### Remove annotators with <100 annotations in train split OR <40 annotations in dev split OR <20 annotations in test split

# %%
aggression_df = aggression_df_full.copy()

annotations_count_in_splits = aggression_df.groupby(['worker_id', 'split'])['rev_id'].agg(['count']).reset_index()

votes_count_train = aggression_df[aggression_df.split.isin(['train'])].groupby('worker_id')['rev_id'].agg('count')
workers_to_remove = votes_count_train[votes_count_train.values < 100].index.tolist()

votes_count_dev = aggression_df[aggression_df.split.isin(['dev'])].groupby('worker_id')['rev_id'].agg('count')
workers_to_remove.extend(votes_count_dev[votes_count_dev.values < 40].index.tolist())

votes_aggresive_count_dev = aggression_df[aggression_df.split.isin(['dev'])].groupby('worker_id')['aggression'].agg('sum')
workers_to_remove.extend(votes_aggresive_count_dev[votes_aggresive_count_dev.values < 20].index.tolist())

votes_not_aggressive_count_dev = votes_count_dev - votes_aggresive_count_dev
workers_to_remove.extend(votes_not_aggressive_count_dev[votes_not_aggressive_count_dev.values < 20].index.tolist())

votes_count_test = aggression_df[aggression_df.split.isin(['test'])].groupby('worker_id')['rev_id'].agg('count')
workers_to_remove.extend(votes_count_test[votes_count_test.values < 20].index.tolist())
workers_to_remove = set(workers_to_remove)

aggression_df = aggression_df[~aggression_df.worker_id.isin(workers_to_remove)]

print(f'Number of annotators with <100 annotations in train set OR <20 in test set = {len(workers_to_remove)}')
# Out:
# Number of annotators with <100 annotations in train set OR <20 in test set = 3248

# %%
print(f"Number of annotators left: {len(set(aggression_df.worker_id))}")
# Out:
# Number of annotators left: 805

# %% [markdown]
# Remove 5 random annotators:

# %%
random_5 = set(np.random.choice(list(set(aggression_df.worker_id)), 5, replace=False))
random_5
# Out:
# {98, 736, 944, 997, 1856}

# %%
aggression_df = aggression_df[~aggression_df.worker_id.isin(random_5)]
print(f"Number of annotators left: {len(set(aggression_df.worker_id))}")
# Out:
# Number of annotators left: 800

# %% [markdown]
# Create folds by annotators:

# %%
def split_by_annotators(df):
    worker_ids = np.random.permutation(list(set(df.worker_id)))
    
    step = 80
    fold_idx = 1
    
    df['fold'] = 0
    for i in range(0, len(worker_ids), step):
        
        if i+step > len(worker_ids):
            break
        
        df.loc[df.worker_id.isin(worker_ids[i:i+step]), 'fold'] = int(fold_idx)
        fold_idx += 1
        
    df = df[df['fold'] > 0]
    
    return df
    
aggression_df = split_by_annotators(aggression_df)

# %% [markdown]
# Fast check to be sure:

# %%
aggression_df.groupby('fold').nunique()
# Out:
#       rev_id  worker_id  aggression  aggression_score  comment  year  \
# fold
# 1      41574         80           2                 7    41541    16
# 2      41826         80           2                 7    41797    16
# 3      42621         80           2                 7    42591    15
# 4      42075         80           2                 7    42040    16
# 5      41680         80           2                 7    41643    16
# 6      39989         80           2                 7    39953    16
# 7      43866         80           2                 7    43831    16
# 8      44046         80           2                 7    44008    15
# 9      43766         80           2                 7    43720    16
# 10     41862         80           2                 7    41829    16
#
#       logged_in  ns  sample  split
# fold
# 1             2   2       2      3
# 2             2   2       2      3
# 3             1   2       2      3
# 4             2   2       2      3
# 5             2   2       2      3
# 6             1   2       2      3
# 7             2   2       2      3
# 8             2   2       2      3
# 9             2   2       2      3
# 10            2   2       2      3

# %% [markdown]
# ### Annotations of texts from train dataset without annotations from users from fold-1

# %%
aggression_df[(aggression_df.fold != 1) & (aggression_df.split == 'train')]
# Out:
#             rev_id  worker_id  aggression  aggression_score  \
# 3            37675       1439         0.0               0.0
# 6            37675        481         0.0               0.0
# 7            37675        487         0.0               0.0
# 8            37675        578         0.0               0.0
# 9            37675       1127         0.0               0.0
# ...            ...        ...         ...               ...
# 1365208  699897151       1887         0.0               0.0
# 1365210  699897151       1608         0.0               0.0
# 1365213  699897151         15         0.0               0.0
# 1365214  699897151         57         0.0               0.0
# 1365215  699897151       1815         0.0               0.0
#
#                                                    comment  year  logged_in  \
# 3        `-NEWLINE_TOKENThis is not ``creative``.  Thos...  2002       True
# 6        `-NEWLINE_TOKENThis is not ``creative``.  Thos...  2002       True
# 7        `-NEWLINE_TOKENThis is not ``creative``.  Thos...  2002       True
# 8        `-NEWLINE_TOKENThis is not ``creative``.  Thos...  2002       True
# 9        `-NEWLINE_TOKENThis is not ``creative``.  Thos...  2002       True
# ...                                                    ...   ...        ...
# 1365208  Alternate option===NEWLINE_TOKENIs there perha...  2016       True
# 1365210  Alternate option===NEWLINE_TOKENIs there perha...  2016       True
# 1365213  Alternate option===NEWLINE_TOKENIs there perha...  2016       True
# 1365214  Alternate option===NEWLINE_TOKENIs there perha...  2016       True
# 1365215  Alternate option===NEWLINE_TOKENIs there perha...  2016       True
#
#               ns   sample  split  fold
# 3        article   random  train     9
# 6        article   random  train     6
# 7        article   random  train    10
# 8        article   random  train     7
# 9        article   random  train     5
# ...          ...      ...    ...   ...
# 1365208  article  blocked  train     3
# 1365210  article  blocked  train     9
# 1365213  article  blocked  train     7
# 1365214  article  blocked  train     2
# 1365215  article  blocked  train     3
#
# [274337 rows x 11 columns]

# %% [markdown]
# ### Annotations of texts from test dataset with annotations only from users from fold-1

# %%
aggression_df[(aggression_df.fold == 1) & (aggression_df.split == 'test')]
# Out:
#             rev_id  worker_id  aggression  aggression_score  \
# 224         286174       2190         0.0               0.0
# 377         386473       1020         0.0               1.0
# 422         421948       3337         0.0               0.0
# 891         916927         72         0.0               1.0
# 902         923974        964         0.0               0.0
# ...            ...        ...         ...               ...
# 1364931  699661834        763         0.0               0.0
# 1365008  699698850       2533         0.0               0.0
# 1365032  699703322       3249         0.0               0.0
# 1365185  699851288         12         0.0               1.0
# 1365187  699851288       2231         0.0               0.0
#
#                                                    comment  year  logged_in  \
# 224      NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLINE...  2002      False
# 377      `NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENNEWLIN...  2002       True
# 422      `NEWLINE_TOKENNEWLINE_TOKEN::: Pointing out wh...  2002       True
# 891      NEWLINE_TOKENNEWLINE_TOKENNEWLINE_TOKENThanks ...  2003       True
# 902      NEWLINE_TOKENNEWLINE_TOKEN:Given that she's on...  2003       True
# ...                                                    ...   ...        ...
# 1364931  `NEWLINE_TOKENNEWLINE_TOKEN== kys ==NEWLINE_TO...  2016       True
# 1365008  NEWLINE_TOKENNEWLINE_TOKENYeah, I realized I c...  2016       True
# 1365032  `NEWLINE_TOKEN:::Yeah and in the earlier sente...  2016       True
# 1365185  NEWLINE_TOKENNEWLINE_TOKENThe Institute for Hi...  2016       True
# 1365187  NEWLINE_TOKENNEWLINE_TOKENThe Institute for Hi...  2016       True
#
#               ns   sample split  fold
# 224      article   random  test     1
# 377         user   random  test     1
# 422      article   random  test     1
# 891         user   random  test     1
# 902         user   random  test     1
# ...          ...      ...   ...   ...
# 1364931     user  blocked  test     1
# 1365008     user  blocked  test     1
# 1365032  article  blocked  test     1
# 1365185  article  blocked  test     1
# 1365187  article  blocked  test     1
#
# [30253 rows x 11 columns]

# %%
aggression_df.loc[:, ['rev_id', 'worker_id', 'aggression', 'aggression_score', 'fold']].to_csv('../data/folded_aggresion_40.csv', index=False)

# %%
folded_aggression = pd.read_csv('../data/folded_aggresion_40.csv')

# %%
folded_aggression#.fold.max()
# Out:
#            rev_id  worker_id  aggression  aggression_score  fold
# 0           37675       1439         0.0               0.0     9
# 1           37675        481         0.0               0.0     6
# 2           37675        487         0.0               0.0    10
# 3           37675        578         0.0               0.0     7
# 4           37675       1127         0.0               0.0     5
# ...           ...        ...         ...               ...   ...
# 545082  699897151       1887         0.0               0.0     3
# 545083  699897151       1608         0.0               0.0     9
# 545084  699897151         15         0.0               0.0     7
# 545085  699897151         57         0.0               0.0     2
# 545086  699897151       1815         0.0               0.0     3
#
# [545087 rows x 5 columns]
